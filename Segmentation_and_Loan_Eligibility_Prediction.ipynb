# %%
# Load the synthetic banking dataset
# Update the path if your CSV is in a different location
df = pd.read_csv(r'D:\OneDrive - wilp.bits-pilani.ac.in\bits\Dissertation\bit_project\bits_project\banking-ml-pipeline\src\data\synthetic_banking_data.csv')

# Display the shape and first few rows
print('Dataset shape:', df.shape)
df.head()
# Out:
# Dataset shape: (500000, 27)
#   customer_id  age  income    education    occupation employment_type  \
# 0  CUST000001   67   93450     Bachelor  Professional         Retired
# 1  CUST000002   64   86585  High School         Sales       Full-time
# 2  CUST000003   64  129887  High School        Manual       Full-time
# 3  CUST000004   55   68890     Bachelor         Sales       Full-time
# 4  CUST000005   77   87096       Master     Executive         Retired
#
#   marital_status  dependents  account_age_months  num_products  ...  \
# 0       Divorced           0                 106             3  ...
# 1       Divorced           1                   9             1  ...
# 2        Married           0                  33             3  ...
# 3        Married           0                  21             1  ...
# 4        Married           4                  52             3  ...
#
#    existing_loans  previous_defaults  payment_history_score  \
# ...
